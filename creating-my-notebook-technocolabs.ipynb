# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")

# %%
my_filepath = "../input/2022-ukraine-russian-war/russia_losses_equipment.csv"

# %%
UKRus_data =my_data =pd.read_csv(my_filepath)

# %%
UKRus_data.head()
